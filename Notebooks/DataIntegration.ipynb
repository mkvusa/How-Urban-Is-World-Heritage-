# %%
import geopandas as gpd

#gdf = gpd.read_file('file.geojson')# https://github.com/mkvusa/heritagezoning/blob/main/Notebooks/HeritageZoneBoundaries/ABC.geojson
#gdf.to_file('file.shp')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\pnourian\Documents\GitHub\heritagezoning\Notebooks\DataIntegration.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pnourian/Documents/GitHub/heritagezoning/Notebooks/DataIntegration.ipynb#ch0000000?line=0'>1</a> import geopandas as gpd
#
# File ~\Miniconda3\envs\equicitypy\lib\site-packages\geopandas\__init__.py:1, in <module>
# ----> <a href='file:///c%3A/Users/pnourian/Miniconda3/envs/equicitypy/lib/site-packages/geopandas/__init__.py?line=0'>1</a> from geopandas._config import options  # noqa
#       <a href='file:///c%3A/Users/pnourian/Miniconda3/envs/equicitypy/lib/site-packages/geopandas/__init__.py?line=2'>3</a> from geopandas.geoseries import GeoSeries  # noqa
# ...
